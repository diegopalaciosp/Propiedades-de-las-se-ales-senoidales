# %% [markdown]
# # Propiedades de las señales senoidales
#
# ## Introducción
# ### ¿Qué es una señal senoidal?
# Lorem
# #### Parámetros
# Lorem
# #### Variable Independiente
# Lorem
# #### Modelo matemático
# Lorem
#
# ## Uso del notebook (Modificación de parámetros)

# %%
from math import sin, pi
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
# if using a jupyter notebook
# %matplotlib inline

def sine_wave(A: float, f: float, phi: float, t: float) -> float:
    return A*sin(2*pi*f*t + phi)

amplitude = 1.
frequency = 1.
phase = 0.
x_max = 2*pi
x_min = 0
step = 0.01

x = np.arange(x_min, x_max, step)
y = [sine_wave(amplitude, frequency, phase, time) for time in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# <p>Concepto señal periódica. Por qué la señal senoidal es periódica. Instrucciones para modificar parámetros</p>

# %%
#Codificacion de las instruccuones
